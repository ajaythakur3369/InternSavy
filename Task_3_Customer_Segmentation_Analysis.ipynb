# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaythakur3369/InternSavy/blob/main/Task_3_Customer_Segmentation_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project - Customer Segmentation Analysis**
# ## **Developed By - Ajay Thakur (ajaythakur3369@gmail.com)**
# ## **Branch Name - Electronics and Communication Engineering**
# ## **Institute Name - Indian Institute of Information Technology Kota (An Institute of National Importance under an Act of Parliament)**
# ## **Submitted To - InternSavy**
# ## **Project Link (GitHub) - [Click here](https://github.com/ajaythakur3369/InternSavy/blob/main/Task_3_Customer_Segmentation_Analysis.ipynb)**
# ## **Project Link (Drive) - [Click here](https://colab.research.google.com/drive/1m3_YQrLKNNoquXcZYYgy8tynH0HgWs7G)**

# %% [markdown]
# # **Problem Statement -**

# %% [markdown]
# Performed Customer Segmentation using Python

# %% [markdown]
# # **Let's Begin !**

# %%
# Import all the required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Access the Drive from Colab, to access the file
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df=pd.read_csv("/content/drive/MyDrive/folders/Mall_Customer.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.drop(columns='CustomerID', inplace=True)

# %%
df.shape
# Out:
# (200, 4)

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  200 non-null    object
#  1   Age                     200 non-null    int64
#  2   Annual Income (k$)      200 non-null    int64
#  3   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %%
df.describe()
# Out:
#               Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000          200.000000              200.000000
# mean    38.850000           60.560000               50.200000
# std     13.969007           26.264721               25.823522
# min     18.000000           15.000000                1.000000
# 25%     28.750000           41.500000               34.750000
# 50%     36.000000           61.500000               50.000000
# 75%     49.000000           78.000000               73.000000
# max     70.000000          137.000000               99.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
sns.countplot(data=df,x='Gender',color='red')
plt.show()

# %%
sns.displot(data=df,x='Annual Income (k$)',color='blue')
plt.show()

# %%
sns.kdeplot(data=df,x='Annual Income (k$)')
plt.show()

# %%
sns.kdeplot(data=df,x='Spending Score (1-100)')
plt.show()

# %%
sns.kdeplot(data=df,x='Age')
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.countplot(data=df,x='Age')
plt.show()

# %%
df.Age.plot(kind='box',figsize=(8,6), title="AGE BoxPlot")
plt.show()

# %% [markdown]
# BiVariant Analysis

# %%
df.plot(kind='scatter' ,x='Age',y='Annual Income (k$)')
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.scatterplot(x='Age', y='Annual Income (k$)', hue='Gender', data=df)
plt.show()

# %%
df.plot(kind='scatter' ,x='Age',y='Spending Score (1-100)')
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.scatterplot(x='Age', y='Spending Score (1-100)', hue='Gender', data=df)
plt.show()

# %%
df.plot(kind='scatter' ,x='Gender',y='Annual Income (k$)')
plt.show()

# %%
df.plot(kind='scatter' ,x='Gender',y='Spending Score (1-100)')
plt.show()

# %% [markdown]
# Multi-Variant Analysis

# %%
import plotly.express as px

fig = px.scatter_3d(df, x='Age', y='Annual Income (k$)', z='Spending Score (1-100)', color='Gender')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
